# %%
import pandas as pd
import pyspark
from pyspark.sql.functions import *
from pyspark.sql import SparkSession

# %% [markdown]
# ## Time Series Daily

# %%
df_mmm = pd.read_json('data/financial/stocks/mmm/daily.json')

# %%
df_mmm.head()
# Out:
#            2021-03-18  2021-03-17  2021-03-16  2021-03-15  2021-03-12  \
# 1. open        188.60      187.33      188.00      186.03      185.61
# 2. high        192.09      189.99      188.46      189.63      186.21
# 3. low         188.60      187.05      185.98      185.71      184.27
# 4. close       191.00      188.30      186.85      189.48      184.92
# 5. volume  3026812.00  2585123.00  2264001.00  3300362.00  2691612.00
#
#              2021-03-11  2021-03-10  2021-03-09  2021-03-08  2021-03-05  ...  \
# 1. open    1.831300e+02      182.37      183.50      180.99      178.45  ...
# 2. high    1.850700e+02      185.38      184.15      185.70      181.56  ...
# 3. low     1.820959e+02      181.41      181.02      180.93      176.95  ...
# 4. close   1.845700e+02      184.51      181.18      183.77      180.80  ...
# 5. volume  2.377493e+06  2370679.00  2842101.00  2574984.00  2262764.00  ...
#
#            1999-11-12  1999-11-11  1999-11-10  1999-11-09  1999-11-08  \
# ...

# %%
df_mmm.tail()
# Out:
#            2021-03-18  2021-03-17  2021-03-16  2021-03-15  2021-03-12  \
# 1. open        188.60      187.33      188.00      186.03      185.61
# 2. high        192.09      189.99      188.46      189.63      186.21
# 3. low         188.60      187.05      185.98      185.71      184.27
# 4. close       191.00      188.30      186.85      189.48      184.92
# 5. volume  3026812.00  2585123.00  2264001.00  3300362.00  2691612.00
#
#              2021-03-11  2021-03-10  2021-03-09  2021-03-08  2021-03-05  ...  \
# 1. open    1.831300e+02      182.37      183.50      180.99      178.45  ...
# 2. high    1.850700e+02      185.38      184.15      185.70      181.56  ...
# 3. low     1.820959e+02      181.41      181.02      180.93      176.95  ...
# 4. close   1.845700e+02      184.51      181.18      183.77      180.80  ...
# 5. volume  2.377493e+06  2370679.00  2842101.00  2574984.00  2262764.00  ...
#
#            1999-11-12  1999-11-11  1999-11-10  1999-11-09  1999-11-08  \
# ...

# %%
df_mmm.dtypes
# Out:
# 2021-03-18    float64
# 2021-03-17    float64
# 2021-03-16    float64
# 2021-03-15    float64
# 2021-03-12    float64
#                ...
# 1999-11-05    float64
# 1999-11-04    float64
# 1999-11-03    float64
# 1999-11-02    float64
# 1999-11-01    float64
# Length: 5379, dtype: object

# %% [markdown]
# ## Time Series Weekly

# %%
df_mmm_weekly = pd.read_json('data/financial/stocks/mmm/weekly.json')

# %%
df_mmm_weekly.head()
# Out:
#             2021-03-18   2021-03-12   2021-03-05   2021-02-26  2021-02-19  \
# 1. open         186.03       180.99       175.70       176.46      179.00
# 2. high         192.09       186.21       181.56       180.75      180.77
# 3. low          185.71       180.93       174.07       173.76      175.14
# 4. close        191.00       184.92       180.80       175.06      176.54
# 5. volume  11176298.00  12856869.00  12178895.00  13246371.00  8487368.00
#
#            2021-02-12    2021-02-05    2021-01-29    2021-01-22   2021-01-15  \
# 1. open        179.30  1.759700e+02  1.688800e+02  1.672600e+02       166.10
# 2. high        182.38  1.792297e+02  1.872700e+02  1.714890e+02       167.74
# 3. low         175.84  1.735500e+02  1.682250e+02  1.668000e+02       163.38
# 4. close       178.70  1.790100e+02  1.756600e+02  1.690400e+02       165.55
# 5. volume  9478257.00  1.194277e+07  2.496985e+07  1.161349e+07  14227510.00
#
# ...

# %%
df_mmm_weekly.tail()
# Out:
#             2021-03-18   2021-03-12   2021-03-05   2021-02-26  2021-02-19  \
# 1. open         186.03       180.99       175.70       176.46      179.00
# 2. high         192.09       186.21       181.56       180.75      180.77
# 3. low          185.71       180.93       174.07       173.76      175.14
# 4. close        191.00       184.92       180.80       175.06      176.54
# 5. volume  11176298.00  12856869.00  12178895.00  13246371.00  8487368.00
#
#            2021-02-12    2021-02-05    2021-01-29    2021-01-22   2021-01-15  \
# 1. open        179.30  1.759700e+02  1.688800e+02  1.672600e+02       166.10
# 2. high        182.38  1.792297e+02  1.872700e+02  1.714890e+02       167.74
# 3. low         175.84  1.735500e+02  1.682250e+02  1.668000e+02       163.38
# 4. close       178.70  1.790100e+02  1.756600e+02  1.690400e+02       165.55
# 5. volume  9478257.00  1.194277e+07  2.496985e+07  1.161349e+07  14227510.00
#
# ...

# %%
df_mmm_weekly.dtypes
# Out:
# 2021-03-18    float64
# 2021-03-12    float64
# 2021-03-05    float64
# 2021-02-26    float64
# 2021-02-19    float64
#                ...
# 1999-12-10    float64
# 1999-12-03    float64
# 1999-11-26    float64
# 1999-11-19    float64
# 1999-11-12    float64
# Length: 1115, dtype: object

# %% [markdown]
# ## Time Series Monthly

# %%
df_mmm_monthly = pd.read_json('data/financial/stocks/mmm/monthly.json')

# %%
df_mmm_monthly.head()
# Out:
#             2021-03-18   2021-02-26   2021-01-29   2020-12-31    2020-11-30  \
# 1. open         175.70       175.97       175.00       174.22  1.621900e+02
# 2. high         192.09       182.38       187.27       177.46  1.796250e+02
# 3. low          174.07       173.55       163.38       169.18  1.599000e+02
# 4. close        191.00       175.06       175.66       174.79  1.727300e+02
# 5. volume  36212062.00  43154764.00  70120337.00  48751666.00  5.359822e+07
#
#             2020-10-30   2020-09-30   2020-08-31   2020-07-31   2020-06-30  \
# 1. open         160.67       162.17       151.09       156.34       155.95
# 2. high         173.19       173.20       167.49       163.38       169.54
# 3. low          156.13       158.07       149.31       148.80       150.10
# 4. close        159.96       160.18       163.02       150.47       155.99
# 5. volume  46222327.00  55990350.00  49410753.00  58624658.00  66941566.00
#
# ...

# %%
df_mmm_monthly.tail()
# Out:
#             2021-03-18   2021-02-26   2021-01-29   2020-12-31    2020-11-30  \
# 1. open         175.70       175.97       175.00       174.22  1.621900e+02
# 2. high         192.09       182.38       187.27       177.46  1.796250e+02
# 3. low          174.07       173.55       163.38       169.18  1.599000e+02
# 4. close        191.00       175.06       175.66       174.79  1.727300e+02
# 5. volume  36212062.00  43154764.00  70120337.00  48751666.00  5.359822e+07
#
#             2020-10-30   2020-09-30   2020-08-31   2020-07-31   2020-06-30  \
# 1. open         160.67       162.17       151.09       156.34       155.95
# 2. high         173.19       173.20       167.49       163.38       169.54
# 3. low          156.13       158.07       149.31       148.80       150.10
# 4. close        159.96       160.18       163.02       150.47       155.99
# 5. volume  46222327.00  55990350.00  49410753.00  58624658.00  66941566.00
#
# ...

# %%
df_mmm_monthly.dtypes
# Out:
# 2021-03-18    float64
# 2021-02-26    float64
# 2021-01-29    float64
# 2020-12-31    float64
# 2020-11-30    float64
#                ...
# 2000-04-28    float64
# 2000-03-31    float64
# 2000-02-29    float64
# 2000-01-31    float64
# 1999-12-31    float64
# Length: 256, dtype: object

# %% [markdown]
# ## Sector

# %%
df_sector = pd.read_json('data/financial/indicators/sector.json')

# %%
df_sector.head(20)
# Out:
#                                                             Meta Data  \
# Information             US Sector Performance (realtime & historical)
# Last Refreshed                         2021-03-18 22:56:20 US/Eastern
# Financials                                                        NaN
# Industrials                                                       NaN
# Health Care                                                       NaN
# Utilities                                                         NaN
# Consumer Staples                                                  NaN
# Materials                                                         NaN
# Real Estate                                                       NaN
# Communication Services                                            NaN
# Consumer Discretionary                                            NaN
# Information Technology                                            NaN
# ...

# %%
df_sector.dtypes
# Out:
# Meta Data                                 object
# Rank A: Real-Time Performance             object
# Rank B: 1 Day Performance                 object
# Rank C: 5 Day Performance                 object
# Rank D: 1 Month Performance               object
# Rank E: 3 Month Performance               object
# Rank F: Year-to-Date (YTD) Performance    object
# Rank G: 1 Year Performance                object
# Rank H: 3 Year Performance                object
# Rank I: 5 Year Performance                object
# Rank J: 10 Year Performance               object
# dtype: object

# %% [markdown]
# ## Unemployment Rate

# %%
df_unemployment = pd.read_json('data/financial/indicators/unemployment.json')

# %%
df_unemployment.head()
# Out:
#             Labor Force Statistics including the National Unemployment Rate
# 1948-01-01                                                3.4
# 1948-02-01                                                3.8
# 1948-03-01                                                4.0
# 1948-04-01                                                3.9
# 1948-05-01                                                3.5

# %%
df_unemployment.tail()
# Out:
#             Labor Force Statistics including the National Unemployment Rate
# 2020-10-01                                                6.9
# 2020-11-01                                                6.7
# 2020-12-01                                                6.7
# 2021-01-01                                                6.3
# 2021-02-01                                                6.2

# %%
df_unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 878 entries, 1948-01-01 to 2021-02-01
# Data columns (total 1 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Labor Force Statistics including the National Unemployment Rate  878 non-null    float64
# dtypes: float64(1)
# memory usage: 13.7 KB

# %%
df_unemployment.describe()
# Out:
#        Labor Force Statistics including the National Unemployment Rate
# count                                         878.000000
# mean                                            5.767768
# std                                             1.705126
# min                                             2.500000
# 25%                                             4.500000
# 50%                                             5.600000
# 75%                                             6.800000
# max                                            14.800000

# %% [markdown]
# ## Consumer Sentiment Index

# %%
df_sentiment = pd.read_json('data/financial/indicators/consumer_sentiment.json')

# %%
df_sentiment.head()
# Out:
#             Index of Consumer Sentiment - monthly
# 1952-11-01                                   86.2
# 1953-02-01                                   90.7
# 1953-08-01                                   80.8
# 1953-11-01                                   80.7
# 1954-02-01                                   82.0

# %%
df_sentiment.tail()
# Out:
#             Index of Consumer Sentiment - monthly
# 2020-10-01                                   81.8
# 2020-11-01                                   76.9
# 2020-12-01                                   80.7
# 2021-01-01                                   79.0
# 2021-02-01                                   76.8

# %%
df_sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 610 entries, 1952-11-01 to 2021-02-01
# Data columns (total 1 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Index of Consumer Sentiment - monthly  610 non-null    float64
# dtypes: float64(1)
# memory usage: 9.5 KB

# %%
df_sentiment.describe()
# Out:
#        Index of Consumer Sentiment - monthly
# count                             610.000000
# mean                               86.534918
# std                                12.286890
# min                                51.700000
# 25%                                77.500000
# 50%                                90.000000
# 75%                                95.300000
# max                               112.000000

# %% [markdown]
# ## Inflation

# %%
df_inflation = pd.read_json('data/financial/indicators/inflation.json')

# %%
df_inflation.head()
# Out:
#             Consumer Price Index (CPI)
# 1956-01-01                    0.374532
# 1956-02-01                    0.374532
# 1956-03-01                    0.374532
# 1956-04-01                    0.749064
# 1956-05-01                    1.123596

# %%
df_inflation.tail()
# Out:
#             Consumer Price Index (CPI)
# 2020-08-01                    1.309645
# 2020-09-01                    1.371325
# 2020-10-01                    1.182066
# 2020-11-01                    1.174536
# 2020-12-01                    1.362005

# %%
df_inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 780 entries, 1956-01-01 to 2020-12-01
# Data columns (total 1 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Consumer Price Index (CPI)  780 non-null    float64
# dtypes: float64(1)
# memory usage: 12.2 KB

# %%
df_inflation.describe()
# Out:
#        Consumer Price Index (CPI)
# count                  780.000000
# mean                     3.588033
# std                      2.780489
# min                     -2.097161
# 25%                      1.727550
# 50%                      2.897597
# 75%                      4.359699
# max                     14.756447

# %% [markdown]
# ## Mortgage Rates

# %%
df_mortgage = pd.read_json('data/financial/indicators/mortgage.json')

# %%
df_mortgage.head()
# Out:
#             Housing affordability index
# 2020-01-01                         3.68
# 2020-02-01                         3.53
# 2020-03-01                         3.51
# 2020-04-01                         3.37
# 2020-05-01                         3.29

# %%
df_mortgage.tail()
# Out:
#             Housing affordability index
# 2020-09-01                         2.95
# 2020-10-01                         2.88
# 2020-11-01                         2.82
# 2020-12-01                         2.73
# 2021-01-01                         2.73

# %%
df_mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13 entries, 2020-01-01 to 2021-01-01
# Data columns (total 1 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Housing affordability index  13 non-null     float64
# dtypes: float64(1)
# memory usage: 208.0 bytes

# %%
df_mortgage.describe()
# Out:
#        Housing affordability index
# count                    13.000000
# mean                      3.137692
# std                       0.319874
# min                       2.730000
# 25%                       2.880000
# 50%                       3.080000
# 75%                       3.370000
# max                       3.680000
